# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

from antipark import *
from antipark.models import Product, Category

# %%
import json

with open('../antipark/db.json', encoding='utf=8', mode='r') as fo:
    data = json.load(fo)

d = {}
for k,v in data['products'].items():
    d[k] = v

# %%
db.create_all()
# Out:
# 2016-09-14 18:31:26,914 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2016-09-14 18:31:26,915 INFO sqlalchemy.engine.base.Engine {}
# 2016-09-14 18:31:27,101 INFO sqlalchemy.engine.base.Engine SELECT DATABASE()
# 2016-09-14 18:31:27,102 INFO sqlalchemy.engine.base.Engine {}
# 2016-09-14 18:31:27,116 INFO sqlalchemy.engine.base.Engine show collation where `Charset` = 'utf8' and `Collation` = 'utf8_bin'
# 2016-09-14 18:31:27,118 INFO sqlalchemy.engine.base.Engine {}
# 2016-09-14 18:31:27,129 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS CHAR(60)) AS anon_1
# 2016-09-14 18:31:27,131 INFO sqlalchemy.engine.base.Engine {}
# 2016-09-14 18:31:27,136 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS CHAR(60)) AS anon_1
# 2016-09-14 18:31:27,139 INFO sqlalchemy.engine.base.Engine {}
# 2016-09-14 18:31:27,145 INFO sqlalchemy.engine.base.Engine SELECT CAST('test collated returns' AS CHAR CHARACTER SET utf8) COLLATE utf8_bin AS anon_1
# 2016-09-14 18:31:27,149 INFO sqlalchemy.engine.base.Engine {}
# 2016-09-14 18:31:27,154 INFO sqlalchemy.engine.base.Engine DESCRIBE `categories`
# 2016-09-14 18:31:27,156 INFO sqlalchemy.engine.base.Engine {}
# 2016-09-14 18:31:27,271 INFO sqlalchemy.engine.base.Engine ROLLBACK
# 2016-09-14 18:31:27,283 INFO sqlalchemy.engine.base.Engine DESCRIBE `products`
# 2016-09-14 18:31:27,285 INFO sqlalchemy.engine.base.Engine {}
# 2016-09-14 18:31:27,302 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE categories (
# 	id INTEGER NOT NULL AUTO_INCREMENT,
# 	category VARCHAR(64),
# 	description TEXT,
# 	PRIMARY KEY (id)
# )
#
#
# 2016-09-14 18:31:27,308 INFO sqlalchemy.engine.base.Engine {}
# 2016-09-14 18:31:27,507 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
# if smth was wrong
# db.session.rollback()

# %%
for category, values in d.items():
    
    description = values['desc']
    
    cat = Category(category=category,
                   description=description,
                  )
    db.session.add(cat)
    db.session.commit()
# Out:
# 2016-09-14 18:34:41,966 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:34:41,973 INFO sqlalchemy.engine.base.Engine INSERT INTO categories (category, description) VALUES (%(category)s, %(description)s)
# 2016-09-14 18:34:41,976 INFO sqlalchemy.engine.base.Engine {'description': 'Парковочные столбики предназначены для ограждения территории от нежелательного проезда автотранспорта. В последнее время в городе существенно увеличивается количество автомобилей. Владельцы транспортных средств любят парковать своих «железных коней» на газонах, пешеходных зонах и тротуарах. Поэтому  столбики часто устанавливают на тротуары по самому краю дороги, для того чтобы предотвратить нежелательную парковку автомобилей и обеспечить проход граждан. Дорожные столбики подразделяются на бетонируемые, анкерные, передвижные, складные и съемные.Бетонируемые столбы крепятся к асфальту или грунту при помощи бетонирования:  сначала в асфальте делается отверстие 30х30см, после чего установленный в него столб заливается бетоном. Бетон застывает в течение 1-2 суток, после чего парковочный столбик готов к использованию: на него может быть прикреплена металлическая цепь или сигнальная лента. Высота бетонированного столбика составляет 1 метр, причем над поверхностью асфальта столбик выступает на 750мм.Анкерные столбы предназначены для крепления в асфальт или бетон. После разметки поверхности «по месту» для установки анкеров в асфальте необходимо просверлить 4 отверстия диаметром 12мм. После чего анкерный парковочный столбик необходимо прикрутить к асфальту при помощи ключа с головкой 13мм. Стоимость анкерного столба несколько выше, чем у бетонируемого, при этом стоимость установки гораздо
INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:36:04,224 INFO sqlalchemy.engine.base.Engine SELECT categories.id AS categories_id, categories.category AS categories_category, categories.description AS categories_description
# FROM categories
# 2016-09-14 18:36:04,227 INFO sqlalchemy.engine.base.Engine {}
# [<antipark.models.Category at 0x7fb4b0ca7e48>,
#  <antipark.models.Category at 0x7fb4b0ca7d68>,
#  <antipark.models.Category at 0x7fb4b0c88ac8>,
#  <antipark.models.Category at 0x7fb4b0c88cc0>,
#  <antipark.models.Category at 0x7fb4b0c887f0>,
#  <antipark.models.Category at 0x7fb4b0c88e80>,
#  <antipark.models.Category at 0x7fb4b0c88f60>,
#  <antipark.models.Category at 0x7fb4b0c88f28>,
#  <antipark.models.Category at 0x7fb4b0c88eb8>,
#  <antipark.models.Category at 0x7fb4b0c88be0>,
#  <antipark.models.Category at 0x7fb4b0c88c88>,
#  <antipark.models.Category at 0x7fb4b0a550b8>,
#  <antipark.models.Category at 0x7fb4b80e4ba8>]

# %%
from collections import namedtuple

Cat = namedtuple('Cat', ['category', 'idx'])
cats = []
for category in categories:
    cat = Cat(category.category, category.id)
    cats.append(cat)

# %%
for category, values in d.items():
    
    for cat in cats:
        if category == cat.category:
            category_id = cat.idx
            break
    
    all_vars = values['variations']
    
    for var in all_vars:
        # prices
        prices = all_vars[var]['prices'].strip('[]').split(', ')
            
        # stage_prices
        stage_prices = all_vars[var]['stage'].strip('[]').split(', ')
            
        # names
        names = all_vars[var]['names'].strip('[]').split(', ')
        
        # subcategory
        subcategory = all_vars[var]['general']
        
        # specs
        chars = all_vars[var]['chars'].strip('[]').split(', ')
        char_values_str = all_vars[var]['values'].split('], [')
        char_values_temp = []
        for ch_v in char_values_str:
            char_values_temp.append(ch_v.strip('[]').split(', '))
                
        specs = []
        print(chars)
        for ch_v in char_values_temp:
            print(ch_v)
            print()
            char_values_dict = {}
            for i, ch in enumerate(ch_v):
                char_values_dict[chars[i]] = ch
            specs.append(str(char_values_dict))
            
        # images
        images_str = all_vars[var]['imgs'].strip('[]').split(', ')
        images = []
        for img in images_str:
            image = all_vars[var]['dest'] + img + ".jpg"
            images.append(image)
            
        
        # commit rec to db
        for i, title in enumerate(names):
            prod = Product(category=category_id,
                           subcategory=subcategory,
                           title=title,
                           specs=specs[i],
                           price=prices[i],
                           stage_price=stage_prices[i],
                           image=images[i],
                           )
            db.session.add(prod)
            db.session.commit()
# Out:
# ['Высота', 'Диаметр корпуса', 'Материал']
# ['750 мм', '76 мм', 'Сталь']
#
# ['750 мм', '76 мм', 'Сталь']
#
# ['750 мм', '76 мм', 'Сталь']
#
# ['750 мм', '76 мм', 'Сталь']
#
# ['850 мм', '76 мм', 'Сталь']
#
# ['750 мм', '76 мм', 'Сталь']
#
# ['805 мм', '108 мм', 'Сталь']
#
# ['805 мм', '108 мм', 'Сталь']
#
# ['1300 мм', 'ГОСТ Р 50970-96', 'ГОСТ Р 50970-96']
#
# ['1500 мм', 'ГОСТ Р 50970-96', 'ГОСТ Р 50970-96']
#
# ['450 мм', '100 мм', 'Полиуретан']
#
# ['800 мм', '100 мм', 'Полиуретан']
#
# ['-', '42 мм', 'Сталь']
#
# ['-', '42 мм', 'Сталь']
#
# ['-', '42 мм', 'Сталь']
#
# ['-', '42 мм', 'Сталь']
#
# ['-', '76 мм', 'Сталь']
#
# ['-', '76 мм', 'Сталь']
#
# ['-', '76 мм', 'Сталь']
#
# ['-', '76 мм', 'Сталь']
#
# ['-', '76 мм', 'Сталь нержавеющая']
#
# ['-', '76 мм', 'Сталь нержавеющая']
#
# ['500 мм', '200 мм', '-']
#
# ['700 мм', '270 мм', '-']
#
# ['500 мм', '270 мм', '-']
#
# ['700 мм', '320 мм', '-']
#
# 2016-09-14 18:47:01,324 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,326 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,327 INFO sqlalchemy.engine.base.Engine {'stage_price': '1199', 'subcategory': '', 'specs': "{'Диаметр корпуса': '76 мм', 'Высота': '750 мм', 'Материал': 'Сталь'}", 'title': 'Столбик парковочный бетонируемый', 'image': 'stolbiki/SB76.jpg', 'price': '899', 'category': 3}
# 2016-09-14 18:47:01,329 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,340 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,341 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,342 INFO sqlalchemy.engine.base.Engine {'stage_price': '399', 'subcategory': '', 'specs': "{'Диаметр корпуса': '76 мм', 'Высота': '750 мм', 'Материал': 'Сталь'}", 'title': 'Столбик парковочный анкерный', 'image': 'stolbiki/SA76.jpg', 'price': '999', 'category': 3}
# 2016-09-14 18:47:01,344 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,349 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,350 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,351 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Диаметр корпуса': '76 мм', 'Высота': '750 мм', 'Материал': 'Сталь'}", 'title': 'Столбик парковочный передвижной', 'image': 'stolbiki/SPR76.jpg', 'price': '1999', 'category': 3}
# 2016-09-14 18:47:01,353 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,368 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,369 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,370 INFO sqlalchemy.engine.base.Engine {'stage_price': '1199', 'subcategory': '', 'specs': "{'Диаметр корпуса': '76 мм', 'Высота': '750 мм', 'Материал': 'Сталь'}", 'title': 'Столбик съемный с бетонируемой закладной', 'image': 'stolbiki/SS76.jpg', 'price': '1999', 'category': 3}
# 2016-09-14 18:47:01,373 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,380 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,384 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,386 INFO sqlalchemy.engine.base.Engine {'stage_price': '1199', 'subcategory': '', 'specs': "{'Диаметр корпуса': '76 мм', 'Высота': '850 мм', 'Материал': 'Сталь'}", 'title': 'Столбик парковочный складной', 'image': 'stolbiki/SSK76.jpg', 'price': '1999', 'category': 3}
# 2016-09-14 18:47:01,389 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,401 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,403 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,404 INFO sqlalchemy.engine.base.Engine {'stage_price': '399', 'subcategory': '', 'specs': "{'Диаметр корпуса': '76 мм', 'Высота': '750 мм', 'Материал': 'Сталь'}", 'title': 'Столбик парковочный евро с анкерным креплением', 'image': 'stolbiki/SE76.jpg', 'price': '910', 'category': 3}
# 2016-09-14 18:47:01,405 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,413 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,414 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,416 INFO sqlalchemy.engine.base.Engine {'stage_price': '1199', 'subcategory': '', 'specs': "{'Диаметр корпуса': '108 мм', 'Высота': '805 мм', 'Материал': 'Сталь'}", 'title': 'Столбик парковочный бетонируемый', 'image': 'stolbiki/SB108.jpg', 'price': '1485', 'category': 3}
# 2016-09-14 18:47:01,418 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,424 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,426 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,427 INFO sqlalchemy.engine.base.Engine {'stage_price': '399', 'subcategory': '', 'specs': "{'Диаметр корпуса': '108 мм', 'Высота': '805 мм', 'Материал': 'Сталь'}", 'title': 'Столбик парковочный анкерный', 'image': 'stolbiki/SA108.jpg', 'price': '1485', 'category': 3}
# 2016-09-14 18:47:01,429 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,435 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,436 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,437 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Диаметр корпуса': 'ГОСТ Р 50970-96', 'Высота': '1300 мм', 'Материал': 'ГОСТ Р 50970-96'}", 'title': 'Столбик дорожный сигнальный', 'image': 'stolbiki/SDS1300.jpg', 'price': '245', 'category': 3}
# 2016-09-14 18:47:01,440 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,449 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,451 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,452 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Диаметр корпуса': 'ГОСТ Р 50970-96', 'Высота': '1500 мм', 'Материал': 'ГОСТ Р 50970-96'}", 'title': 'Столбик дорожный сигнальный', 'image': 'stolbiki/SDS1500.jpg', 'price': '245', 'category': 3}
# 2016-09-14 18:47:01,454 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,459 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,461 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,461 INFO sqlalchemy.engine.base.Engine {'stage_price': '399', 'subcategory': '', 'specs': "{'Диаметр корпуса': '100 мм', 'Высота': '450 мм', 'Материал': 'Полиуретан'}", 'title': 'Столбик разделительный гибкий', 'image': 'stolbiki/STG450.jpg', 'price': '-', 'category': 3}
# 2016-09-14 18:47:01,464 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,469 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,471 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,472 INFO sqlalchemy.engine.base.Engine {'stage_price': '399', 'subcategory': '', 'specs': "{'Диаметр корпуса': '100 мм', 'Высота': '800 мм', 'Материал': 'Полиуретан'}", 'title': 'Столбик разделительный гибкий', 'image': 'stolbiki/STG800.jpg', 'price': '1199', 'category': 3}
# 2016-09-14 18:47:01,474 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,480 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,485 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,486 INFO sqlalchemy.engine.base.Engine {'stage_price': '399', 'subcategory': '', 'specs': "{'Диаметр корпуса': '42 мм', 'Высота': '-', 'Материал': 'Сталь'}", 'title': 'Парковочный столбик с анкерным креплением', 'image': 'stolbiki/ST42A.jpg', 'price': '-', 'category': 3}
# 2016-09-14 18:47:01,488 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,494 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,495 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,496 INFO sqlalchemy.engine.base.Engine {'stage_price': '399', 'subcategory': '', 'specs': "{'Диаметр корпуса': '42 мм', 'Высота': '-', 'Материал': 'Сталь'}", 'title': 'Парковочный столбик с анкерным креплением и ухом для цепи', 'image': 'stolbiki/ST42AU.jpg', 'price': '-', 'category': 3}
# 2016-09-14 18:47:01,499 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,505 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,506 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,507 INFO sqlalchemy.engine.base.Engine {'stage_price': '1199', 'subcategory': '', 'specs': "{'Диаметр корпуса': '42 мм', 'Высота': '-', 'Материал': 'Сталь'}", 'title': 'Парковочный столбик бетонируемый', 'image': 'stolbiki/ST42B.jpg', 'price': '-', 'category': 3}
# 2016-09-14 18:47:01,509 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,515 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,516 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,518 INFO sqlalchemy.engine.base.Engine {'stage_price': '1199', 'subcategory': '', 'specs': "{'Диаметр корпуса': '42 мм', 'Высота': '-', 'Материал': 'Сталь'}", 'title': 'Парковочный столбик бетонируемый с ухом для цепи', 'image': 'stolbiki/ST42BU.jpg', 'price': '-', 'category': 3}
# 2016-09-14 18:47:01,520 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,526 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,527 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,529 INFO sqlalchemy.engine.base.Engine {'stage_price': '399', 'subcategory': '', 'specs': "{'Диаметр корпуса': '76 мм', 'Высота': '-', 'Материал': 'Сталь'}", 'title': 'Парковочный столбик с анкерным креплением', 'image': 'stolbiki/ST76A.jpg', 'price': '-', 'category': 3}
# 2016-09-14 18:47:01,531 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,537 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,538 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,539 INFO sqlalchemy.engine.base.Engine {'stage_price': '399', 'subcategory': '', 'specs': "{'Диаметр корпуса': '76 мм', 'Высота': '-', 'Материал': 'Сталь'}", 'title': 'Парковочный столбик с анкерным креплением и ухом для цепи', 'image': 'stolbiki/ST76AU.jpg', 'price': '-', 'category': 3}
# 2016-09-14 18:47:01,542 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,549 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,550 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,551 INFO sqlalchemy.engine.base.Engine {'stage_price': '1199', 'subcategory': '', 'specs': "{'Диаметр корпуса': '76 мм', 'Высота': '-', 'Материал': 'Сталь'}", 'title': 'Столбик бетонируемый', 'image': 'stolbiki/ST76B.jpg', 'price': '-', 'category': 3}
# 2016-09-14 18:47:01,554 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,560 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,562 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,569 INFO sqlalchemy.engine.base.Engine {'stage_price': '1199', 'subcategory': '', 'specs': "{'Диаметр корпуса': '76 мм', 'Высота': '-', 'Материал': 'Сталь'}", 'title': 'Столбик бетонируемый с ухом для цепи', 'image': 'stolbiki/ST76BU.jpg', 'price': '-', 'category': 3}
# 2016-09-14 18:47:01,574 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,580 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,581 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,584 INFO sqlalchemy.engine.base.Engine {'stage_price': '1199', 'subcategory': '', 'specs': "{'Диаметр корпуса': '76 мм', 'Высота': '-', 'Материал': 'Сталь нержавеющая'}", 'title': 'Столбик из нержавеющей стали бетонируемый', 'image': 'stolbiki/STN76B.jpg', 'price': '-', 'category': 3}
# 2016-09-14 18:47:01,586 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,594 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,596 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,598 INFO sqlalchemy.engine.base.Engine {'stage_price': '1199', 'subcategory': '', 'specs': "{'Диаметр корпуса': '76 мм', 'Высота': '-', 'Материал': 'Сталь нержавеющая'}", 'title': 'Столбик из нержавеющей стали для бетонирования', 'image': 'stolbiki/STN76BU.jpg', 'price': '-', 'category': 3}
# 2016-09-14 18:47:01,600 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,606 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,607 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,608 INFO sqlalchemy.engine.base.Engine {'stage_price': '75000', 'subcategory': '', 'specs': "{'Диаметр корпуса': '200 мм', 'Высота': '500 мм', 'Материал': '-'}", 'title': 'Столбик выдвижной электромеханический', 'image': 'stolbiki/SVE200.jpg', 'price': '105000', 'category': 3}
# 2016-09-14 18:47:01,611 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,617 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,618 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,619 INFO sqlalchemy.engine.base.Engine {'stage_price': '99000', 'subcategory': '', 'specs': "{'Диаметр корпуса': '270 мм', 'Высота': '700 мм', 'Материал': '-'}", 'title': 'Столбик выдвижной гидравлический', 'image': 'stolbiki/SVG270.jpg', 'price': '158000', 'category': 3}
# 2016-09-14 18:47:01,621 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,628 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,629 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,630 INFO sqlalchemy.engine.base.Engine {'stage_price': '75000', 'subcategory': '', 'specs': "{'Диаметр корпуса': '270 мм', 'Высота': '500 мм', 'Материал': '-'}", 'title': 'Столбик парковочный передвижной', 'image': 'stolbiki/SVE270.jpg', 'price': '115000', 'category': 3}
# 2016-09-14 18:47:01,633 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,639 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,640 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,641 INFO sqlalchemy.engine.base.Engine {'stage_price': '99000', 'subcategory': '', 'specs': "{'Диаметр корпуса': '320 мм', 'Высота': '700 мм', 'Материал': '-'}", 'title': 'Столбик парковочный евро с анкерным креплением', 'image': 'stolbiki/SVG320.jpg', 'price': '184000', 'category': 3}
# 2016-09-14 18:47:01,643 INFO sqlalchemy.engine.base.Engine COMMIT
# ['Высота', 'Вес', 'Материал']
# ['316 мм', '0.2 кг', 'пластик']
#
# ['1200 мм', '0.4 кг', 'пластик']
#
# ['520 мм', '0.8 кг', 'пластик']
#
# [' 577 мм', '1 кг', 'пластик']
#
# [' 520 мм', '3 кг', 'пластик']
#
# ['577мм', '3.2 кг', 'пластик']
#
# ['1200 мм', '0.6 кг', 'пластик']
#
# ['520 мм', '0.8 кг', 'пластик']
#
# 2016-09-14 18:47:01,649 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,650 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,651 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Вес': '0.2 кг', 'Высота': '316 мм', 'Материал': 'пластик'}", 'title': 'Конус сигнальный', 'image': 'conusi/kzh320.jpg', 'price': '119', 'category': 4}
# 2016-09-14 18:47:01,652 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,658 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,659 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,660 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Вес': '0.4 кг', 'Высота': '1200 мм', 'Материал': 'пластик'}", 'title': 'Автоконус с вехой', 'image': 'conusi/kzh320v.jpg', 'price': '279', 'category': 4}
# 2016-09-14 18:47:01,662 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,668 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,669 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,670 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Вес': '0.8 кг', 'Высота': '520 мм', 'Материал': 'пластик'}", 'title': 'Конус дорожный', 'image': 'conusi/kzh520.jpg', 'price': '279', 'category': 4}
# 2016-09-14 18:47:01,672 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,678 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,680 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,680 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Вес': '1 кг', 'Высота': ' 577 мм', 'Материал': 'пластик'}", 'title': 'Конус дорожный с ухом для цепи', 'image': 'conusi/kzh520.jpg', 'price': '369', 'category': 4}
# 2016-09-14 18:47:01,682 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,688 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,689 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,690 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Вес': '3 кг', 'Высота': ' 520 мм', 'Материал': 'пластик'}", 'title': 'Конус дорожный с утяжелителем', 'image': 'conusi/kzh520.jpg', 'price': '499', 'category': 4}
# 2016-09-14 18:47:01,691 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,697 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,698 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,699 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Вес': '3.2 кг', 'Высота': '577мм', 'Материал': 'пластик'}", 'title': 'Конус дорожный с утяжелитем и ухом для цепи', 'image': 'conusi/kzh520.jpg', 'price': '599', 'category': 4}
# 2016-09-14 18:47:01,700 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,706 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,707 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,708 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Вес': '0.6 кг', 'Высота': '1200 мм', 'Материал': 'пластик'}", 'title': 'Автоконус с вехой', 'image': 'conusi/kzh520v.jpg', 'price': '449', 'category': 4}
# 2016-09-14 18:47:01,710 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,717 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,718 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,719 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Вес': '0.8 кг', 'Высота': '520 мм', 'Материал': 'пластик'}", 'title': 'Конус парковочный мягкий', 'image': 'conusi/kzh520.jpg', 'price': '299', 'category': 4}
# 2016-09-14 18:47:01,720 INFO sqlalchemy.engine.base.Engine COMMIT
# ['Объём', 'Вес']
# ['25л', '1кг']
#
# ['20л', '1кг']
#
# ['20л', '1кг']
#
# 2016-09-14 18:47:01,726 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,727 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,728 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Вес': '1кг', 'Объём': '25л'}", 'title': 'Круглый вкладыш для бетонной урны оцинкованный', 'image': 'urni/round.jpg', 'price': '499', 'category': 5}
# 2016-09-14 18:47:01,730 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,735 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,736 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,737 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Вес': '1кг', 'Объём': '20л'}", 'title': 'Квадратный вкладыш для бетонной урны оцинкованный', 'image': 'urni/square.jpg', 'price': '-', 'category': 5}
# 2016-09-14 18:47:01,739 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,744 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,745 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,746 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Вес': '1кг', 'Объём': '20л'}", 'title': 'Треугольный вкладыш для бетонной урны оцинкованный', 'image': 'urni/triangle.jpg', 'price': '-', 'category': 5}
# 2016-09-14 18:47:01,747 INFO sqlalchemy.engine.base.Engine COMMIT
# ['Размеры', 'Объём', 'Вес']
# ['470х470х620', '20л', '150кг']
#
# ['400х400х520', '25л', '108кг']
#
# ['400х400х520', '20л', '80кг']
#
# ['400х400х520', '20л', '80кг']
#
# ['750х750х900', '20л', '100кг']
#
# ['400х400х520', '20л', '80кг']
#
# ['400х400х520', '20л', '80кг']
#
# ['400х400х520', '20л', '80кг']
#
# ['400х400х520', '20л', '80кг']
#
# ['400х400х500', '25л', '100кг']
#
# ['420х420х500', '25л', '120кг']
#
# ['420х420х500', '25л', '120кг']
#
# 2016-09-14 18:47:01,753 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,754 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,755 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Вес': '150кг', 'Объём': '20л', 'Размеры': '470х470х620'}", 'title': 'Тяжелая бетонная урна для мусора', 'image': 'urni/1.jpg', 'price': '1999', 'category': 5}
# 2016-09-14 18:47:01,756 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,762 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,763 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,765 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Вес': '108кг', 'Объём': '25л', 'Размеры': '400х400х520'}", 'title': 'Стандартная бетонная урна', 'image': 'urni/2.jpg', 'price': '1599', 'category': 5}
# 2016-09-14 18:47:01,768 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,774 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,775 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,776 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Вес': '80кг', 'Объём': '20л', 'Размеры': '400х400х520'}", 'title': 'Урна бетонная эконом', 'image': 'urni/3.jpg', 'price': '2599', 'category': 5}
# 2016-09-14 18:47:01,779 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,784 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,786 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,787 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Вес': '80кг', 'Объём': '20л', 'Размеры': '400х400х520'}", 'title': 'Урна бетонная капля', 'image': 'urni/4.jpg', 'price': '2699', 'category': 5}
# 2016-09-14 18:47:01,790 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,795 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,796 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,799 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Вес': '100кг', 'Объём': '20л', 'Размеры': '750х750х900'}", 'title': 'Урна бетонная уличная для мусора', 'image': 'urni/urna.jpg', 'price': '2699', 'category': 5}
# 2016-09-14 18:47:01,802 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,807 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,809 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,811 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Вес': '80кг', 'Объём': '20л', 'Размеры': '400х400х520'}", 'title': 'Урна уличная для мусора', 'image': 'urni/urna.jpg', 'price': '2699', 'category': 5}
# 2016-09-14 18:47:01,813 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,820 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,821 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,823 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Вес': '80кг', 'Объём': '20л', 'Размеры': '400х400х520'}", 'title': 'Урна бетонная волна', 'image': 'urni/wave.jpg', 'price': '2699', 'category': 5}
# 2016-09-14 18:47:01,825 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,832 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,833 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,834 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Вес': '80кг', 'Объём': '20л', 'Размеры': '400х400х520'}", 'title': 'Урна для мусора', 'image': 'urni/urna.jpg', 'price': '2699', 'category': 5}
# 2016-09-14 18:47:01,836 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,842 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,843 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,845 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Вес': '80кг', 'Объём': '20л', 'Размеры': '400х400х520'}", 'title': 'Урна бетонная ромб', 'image': 'urni/romb.jpg', 'price': '2699', 'category': 5}
# 2016-09-14 18:47:01,848 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,854 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,855 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,857 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Вес': '100кг', 'Объём': '25л', 'Размеры': '400х400х500'}", 'title': 'Парковая урна для мусора', 'image': 'urni/park.jpg', 'price': '2699', 'category': 5}
# 2016-09-14 18:47:01,859 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,865 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,866 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,867 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Вес': '120кг', 'Объём': '25л', 'Размеры': '420х420х500'}", 'title': 'Тяжелая бетонная урна', 'image': 'urni/park.jpg', 'price': '1999', 'category': 5}
# 2016-09-14 18:47:01,870 INFO sqlalchemy.engine.base.Engine COMMIT
# ['Материал', 'Тип', 'Размеры']
# ['Пластик', 'Накладной', '110х71х65 мм']
#
# 2016-09-14 18:47:01,876 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,877 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,879 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Тип': 'Накладной', 'Размеры': '110х71х65 мм', 'Материал': 'Пластик'}", 'title': 'Пост управления шлагбаумом', 'image': 'shlagbaumi/b.jpg', 'price': '300', 'category': 6}
# 2016-09-14 18:47:01,881 INFO sqlalchemy.engine.base.Engine COMMIT
# ['Дальность', '']
# ['20 м', 'Брелок в комплекте']
#
# 2016-09-14 18:47:01,887 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,888 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,890 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'': 'Брелок в комплекте', 'Дальность': '20 м'}", 'title': 'Система радиоуправления выносная', 'image': 'shlagbaumi/b.jpg', 'price': '1900', 'category': 6}
# 2016-09-14 18:47:01,893 INFO sqlalchemy.engine.base.Engine COMMIT
# ['Стрела', 'Заглушка']
# ['Алюминий', 'Пластик']
#
# ['Алюминий', 'Пластик']
#
# ['Алюминий', 'Пластик']
#
# 2016-09-14 18:47:01,900 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,901 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,902 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Заглушка': 'Пластик', 'Стрела': 'Алюминий'}", 'title': 'Рейка для шлагбаума CAME 2.7 м', 'image': 'shlagbaumi/b.jpg', 'price': '1800', 'category': 6}
# 2016-09-14 18:47:01,904 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,910 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,911 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,912 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Заглушка': 'Пластик', 'Стрела': 'Алюминий'}", 'title': 'Рейка для шлагбаума CAME 4.2 м', 'image': 'shlagbaumi/b.jpg', 'price': '2700', 'category': 6}
# 2016-09-14 18:47:01,915 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,920 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,921 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,923 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Заглушка': 'Пластик', 'Стрела': 'Алюминий'}", 'title': 'Рейка для шлагбаума CAME 6.85 м', 'image': 'shlagbaumi/b.jpg', 'price': '6900', 'category': 6}
# 2016-09-14 18:47:01,925 INFO sqlalchemy.engine.base.Engine COMMIT
# ['Длина', 'Комплект']
# ['4 м', '2 шт']
#
# ['4 м', '2 шт']
#
# ['6 м', '2 шт']
#
# ['6 м', '2 шт']
#
# 2016-09-14 18:47:01,931 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,933 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,934 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Комплект': '2 шт', 'Длина': '4 м'}", 'title': 'Ребра безопасности рейки шлагбаума CAME', 'image': 'shlagbaumi/b.jpg', 'price': '2000', 'category': 6}
# 2016-09-14 18:47:01,938 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,943 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,944 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,945 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Комплект': '2 шт', 'Длина': '4 м'}", 'title': 'Ребра безопасности рейки шлагбаума NICE', 'image': 'shlagbaumi/b.jpg', 'price': '1800', 'category': 6}
# 2016-09-14 18:47:01,949 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,954 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,955 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,957 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Комплект': '2 шт', 'Длина': '6 м'}", 'title': 'Ребра безопасности рейки шлагбаума CAME', 'image': 'shlagbaumi/b.jpg', 'price': '3400', 'category': 6}
# 2016-09-14 18:47:01,959 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,965 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,966 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,967 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Комплект': '2 шт', 'Длина': '6 м'}", 'title': 'Ребра безопасности рейки шлагбаума NICE', 'image': 'shlagbaumi/b.jpg', 'price': '2700', 'category': 6}
# 2016-09-14 18:47:01,970 INFO sqlalchemy.engine.base.Engine COMMIT
# ['Дальность', 'Каналы', 'Тип']
# ['50м', '2 канала', 'Радиобрелок']
#
# ['50м', '2 канала', 'Канальный брелок']
#
# 2016-09-14 18:47:01,975 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,976 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,978 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Дальность': '50м', 'Тип': 'Радиобрелок', 'Каналы': '2 канала'}", 'title': 'Система радиоуправления шлагбаумом', 'image': 'shlagbaumi/b.jpg', 'price': '2750', 'category': 6}
# 2016-09-14 18:47:01,981 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:01,986 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,987 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:01,989 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Дальность': '50м', 'Тип': 'Канальный брелок', 'Каналы': '2 канала'}", 'title': 'Система радиоуправления шлагбаумом', 'image': 'shlagbaumi/b.jpg', 'price': '4100', 'category': 6}
# 2016-09-14 18:47:01,992 INFO sqlalchemy.engine.base.Engine COMMIT
# ['Размеры', 'Работа']
# ['32х68х13 мм', 'от другого брелка']
#
# ['32х68х13 мм', 'от другого брелка']
#
# ['40х85х12 мм', 'от другого брелка']
#
# ['40х85х12 мм', 'от другого брелка']
#
# ['28х61х8 мм', 'программируемый']
#
# 2016-09-14 18:47:01,998 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:01,999 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:02,000 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Размеры': '32х68х13 мм', 'Работа': 'от другого брелка'}", 'title': 'Радиобрелок с двумя кнопками', 'image': 'shlagbaumi/b.jpg', 'price': '1000', 'category': 6}
# 2016-09-14 18:47:02,003 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:02,009 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:02,010 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:02,011 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Размеры': '32х68х13 мм', 'Работа': 'от другого брелка'}", 'title': 'Радиобрелок с двумя кнопками', 'image': 'shlagbaumi/b.jpg', 'price': '900', 'category': 6}
# 2016-09-14 18:47:02,014 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:02,019 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:02,020 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:02,024 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Размеры': '40х85х12 мм', 'Работа': 'от другого брелка'}", 'title': 'Радиобрелок с четырмя кнопками', 'image': 'shlagbaumi/b.jpg', 'price': '1300', 'category': 6}
# 2016-09-14 18:47:02,026 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:02,031 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:02,032 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:02,034 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Размеры': '40х85х12 мм', 'Работа': 'от другого брелка'}", 'title': 'Радиобрелок с четырмя кнопками', 'image': 'shlagbaumi/b.jpg', 'price': '950', 'category': 6}
# 2016-09-14 18:47:02,036 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:02,041 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:02,042 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:02,043 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'Размеры': '28х61х8 мм', 'Работа': 'программируемый'}", 'title': 'Радиобрелок с четырмя кнопками', 'image': 'shlagbaumi/b.jpg', 'price': 'от 490', 'category': 6}
# 2016-09-14 18:47:02,044 INFO sqlalchemy.engine.base.Engine COMMIT
# ['']
# ['Накладного типа (до 25м)']
#
# ['Врезного типа (до 18м)']
#
# ['Накладного типа (до 10м)']
#
# ['В комплекте с закладной DOC-L']
#
# ['В комплекте с закладной DIR-L']
#
# ['CAME/Doorhan']
#
# 2016-09-14 18:47:02,050 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:02,051 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:02,052 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'': 'Накладного типа (до 25м)'}", 'title': 'Фотоэлементы безопасности Doorhan', 'image': 'shlagbaumi/b.jpg', 'price': '1500', 'category': 6}
# 2016-09-14 18:47:02,053 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:02,058 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:02,059 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:02,060 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'': 'Врезного типа (до 18м)'}", 'title': 'Фотоэлементы CAME', 'image': 'shlagbaumi/b.jpg', 'price': '2000', 'category': 6}
# 2016-09-14 18:47:02,062 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:02,067 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:02,068 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:02,069 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'': 'Накладного типа (до 10м)'}", 'title': 'Фотоэлементы CAME', 'image': 'shlagbaumi/b.jpg', 'price': '2000', 'category': 6}
# 2016-09-14 18:47:02,071 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:02,076 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:02,077 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:02,078 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': '', 'specs': "{'': 'В комплекте с закладной DOC-L'}", 'title': 'Стойка для DOC-элементов', 'image': 'shlagbaumi/b.jpg', 'price': '1250', 'category': 6}
# 2016-09-14 18:47:02,080 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:02,085 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:02,086 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# ...
# 2016-09-14 18:47:04,382 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': 'Лента сигнальная Теплосеть - ЛСВ', 'specs': "{'Толщина': '200 мкм', 'Ширина': '200 мм', 'Размер': '250 п.м.'}", 'title': 'Лента Внимание водопровод', 'image': 'lenti/att.jpg', 'price': '1795', 'category': 14}
# 2016-09-14 18:47:04,383 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:04,389 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:04,390 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:04,391 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': 'Лента сигнальная Теплосеть - ЛСВ', 'specs': "{'Толщина': '200 мкм', 'Ширина': '200 мм', 'Размер': '150 п.м.'}", 'title': 'Лента Внимание водопровод', 'image': 'lenti/att.jpg', 'price': '1314', 'category': 14}
# 2016-09-14 18:47:04,393 INFO sqlalchemy.engine.base.Engine COMMIT
# ['Ширина', 'Толщина', 'Размер']
# ['50 мм', '35 мкм', '150 п.м.']
#
# ['50 мм', '35 мкм', '200 п.м.']
#
# ['75 мм', '35 мкм', '200 п.м.']
#
# ['75 мм', '50 мкм', '100 п.м.']
#
# ['75 мм', '50 мкм', '250 п.м.']
#
# ['75 мм', '50 мкм', '500 п.м.']
#
# ['75 мм', '80 мкм', '250 п.м.']
#
# ['75 мм', '50 мкм', '250 п.м.']
#
# ['75 мм', '50 мкм', '250 п.м.']
#
# ['75 мм', '50 мкм', '250 п.м.']
#
# ['75 мм', '50 мкм', '250 п.м.']
#
# ['100 мм', '50 мкм', '250 п.м.']
#
# 2016-09-14 18:47:04,399 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:04,400 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:04,400 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': 'Оградительная лента', 'specs': "{'Толщина': '35 мкм', 'Ширина': '50 мм', 'Размер': '150 п.м.'}", 'title': 'Лента оградительная Эконом', 'image': 'lenti/eco.jpg', 'price': '-', 'category': 14}
# 2016-09-14 18:47:04,402 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:04,408 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:04,409 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:04,410 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': 'Оградительная лента', 'specs': "{'Толщина': '35 мкм', 'Ширина': '50 мм', 'Размер': '200 п.м.'}", 'title': 'Лента оградительная Эконом', 'image': 'lenti/eco.jpg', 'price': '104', 'category': 14}
# 2016-09-14 18:47:04,412 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:04,417 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:04,418 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:04,419 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': 'Оградительная лента', 'specs': "{'Толщина': '35 мкм', 'Ширина': '75 мм', 'Размер': '200 п.м.'}", 'title': 'Лента оградительная Эконом', 'image': 'lenti/eco.jpg', 'price': '132', 'category': 14}
# 2016-09-14 18:47:04,421 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:04,426 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:04,427 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:04,428 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': 'Оградительная лента', 'specs': "{'Толщина': '50 мкм', 'Ширина': '75 мм', 'Размер': '100 п.м.'}", 'title': 'Лента оградительная Стандарт', 'image': 'lenti/standart.jpg', 'price': '-', 'category': 14}
# 2016-09-14 18:47:04,430 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:04,435 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:04,436 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:04,437 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': 'Оградительная лента', 'specs': "{'Толщина': '50 мкм', 'Ширина': '75 мм', 'Размер': '250 п.м.'}", 'title': 'Лента оградительная Стандарт', 'image': 'lenti/standart.jpg', 'price': '198', 'category': 14}
# 2016-09-14 18:47:04,438 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:04,444 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:04,445 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:04,447 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': 'Оградительная лента', 'specs': "{'Толщина': '50 мкм', 'Ширина': '75 мм', 'Размер': '500 п.м.'}", 'title': 'Лента оградительная Стандарт', 'image': 'lenti/standart.jpg', 'price': '-', 'category': 14}
# 2016-09-14 18:47:04,449 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:04,455 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:04,456 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:04,458 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': 'Оградительная лента', 'specs': "{'Толщина': '80 мкм', 'Ширина': '75 мм', 'Размер': '250 п.м.'}", 'title': 'Лента оградительная Усиленная', 'image': 'lenti/str.jpg', 'price': '-', 'category': 14}
# 2016-09-14 18:47:04,460 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:04,466 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:04,467 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:04,468 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': 'Оградительная лента', 'specs': "{'Толщина': '50 мкм', 'Ширина': '75 мм', 'Размер': '250 п.м.'}", 'title': 'Лента оградительная Опасная зона!', 'image': 'lenti/lenta.jpg', 'price': '213', 'category': 14}
# 2016-09-14 18:47:04,471 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:04,476 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:04,477 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:04,481 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': 'Оградительная лента', 'specs': "{'Толщина': '50 мкм', 'Ширина': '75 мм', 'Размер': '250 п.м.'}", 'title': 'Лента оградительная Проход запрещен!', 'image': 'lenti/lenta.jpg', 'price': '360', 'category': 14}
# 2016-09-14 18:47:04,483 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:04,489 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:04,489 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:04,491 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': 'Оградительная лента', 'specs': "{'Толщина': '50 мкм', 'Ширина': '75 мм', 'Размер': '250 п.м.'}", 'title': 'Лента оградительная Внимание ДТП', 'image': 'lenti/lenta.jpg', 'price': '213', 'category': 14}
# 2016-09-14 18:47:04,494 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:04,499 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:04,500 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:04,502 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': 'Оградительная лента', 'specs': "{'Толщина': '50 мкм', 'Ширина': '75 мм', 'Размер': '250 п.м.'}", 'title': 'Лента оградительная Опасная зона МЧС России телефон 01', 'image': 'lenti/lenta.jpg', 'price': '213', 'category': 14}
# 2016-09-14 18:47:04,505 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:04,510 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:04,511 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:04,513 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': 'Оградительная лента', 'specs': "{'Толщина': '50 мкм', 'Ширина': '100 мм', 'Размер': '250 п.м.'}", 'title': 'Лента оградительная Зона таможенного контроля', 'image': 'lenti/lenta.jpg', 'price': '261', 'category': 14}
# 2016-09-14 18:47:04,515 INFO sqlalchemy.engine.base.Engine COMMIT
# ['Ширина', 'Толщина', 'Размер']
# ['200 мм', '200 мкм', '250 п.м.']
#
# ['200 мм', '200 мкм', '150 п.м.']
#
# 2016-09-14 18:47:04,520 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:04,521 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:04,522 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': 'Лента сигнальная Теплосеть - ЛСТ', 'specs': "{'Толщина': '200 мкм', 'Ширина': '200 мм', 'Размер': '250 п.м.'}", 'title': 'Лента Внимание теплосеть', 'image': 'lenti/att.jpg', 'price': '1795', 'category': 14}
# 2016-09-14 18:47:04,525 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:04,532 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:04,533 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:04,534 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': 'Лента сигнальная Теплосеть - ЛСТ', 'specs': "{'Толщина': '200 мкм', 'Ширина': '200 мм', 'Размер': '150 п.м.'}", 'title': 'Лента Внимание теплосеть', 'image': 'lenti/att.jpg', 'price': '1314', 'category': 14}
# 2016-09-14 18:47:04,536 INFO sqlalchemy.engine.base.Engine COMMIT
# ['Ширина', 'Толщина', 'Размер']
# ['150 мм', '300 мкм', '100 п.м.']
#
# ['250 мм', '300 мкм', '100 п.м.']
#
# ['300 мм', '300 мкм', '100 п.м.']
#
# ['450 мм', '300 мкм', '100 п.м.']
#
# ['600 мм', '300 мкм', '100 п.м.']
#
# ['750 мм', '300 мкм', '100 п.м.']
#
# ['900 мм', '300 мкм', '100 п.м.']
#
# 2016-09-14 18:47:04,542 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:04,543 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:04,544 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': 'Лента сигнальная Электра - ЛСЭ', 'specs': "{'Толщина': '300 мкм', 'Ширина': '150 мм', 'Размер': '100 п.м.'}", 'title': 'Лента ОСТОРОЖНО КАБЕЛЬ', 'image': 'lenti/kab.jpg', 'price': '612', 'category': 14}
# 2016-09-14 18:47:04,547 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:04,552 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:04,553 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:04,555 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': 'Лента сигнальная Электра - ЛСЭ', 'specs': "{'Толщина': '300 мкм', 'Ширина': '250 мм', 'Размер': '100 п.м.'}", 'title': 'Лента ОСТОРОЖНО КАБЕЛЬ', 'image': 'lenti/kab.jpg', 'price': '1029', 'category': 14}
# 2016-09-14 18:47:04,557 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:04,564 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:04,565 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:04,566 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': 'Лента сигнальная Электра - ЛСЭ', 'specs': "{'Толщина': '300 мкм', 'Ширина': '300 мм', 'Размер': '100 п.м.'}", 'title': 'Лента ОСТОРОЖНО КАБЕЛЬ', 'image': 'lenti/kab.jpg', 'price': '1226', 'category': 14}
# 2016-09-14 18:47:04,568 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:04,574 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:04,576 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:04,577 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': 'Лента сигнальная Электра - ЛСЭ', 'specs': "{'Толщина': '300 мкм', 'Ширина': '450 мм', 'Размер': '100 п.м.'}", 'title': 'Лента ОСТОРОЖНО КАБЕЛЬ', 'image': 'lenti/kab.jpg', 'price': '1829', 'category': 14}
# 2016-09-14 18:47:04,580 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:04,585 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:04,587 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:04,587 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': 'Лента сигнальная Электра - ЛСЭ', 'specs': "{'Толщина': '300 мкм', 'Ширина': '600 мм', 'Размер': '100 п.м.'}", 'title': 'Лента ОСТОРОЖНО КАБЕЛЬ', 'image': 'lenti/kab.jpg', 'price': '2482', 'category': 14}
# 2016-09-14 18:47:04,589 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:04,595 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:04,596 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
# 2016-09-14 18:47:04,597 INFO sqlalchemy.engine.base.Engine {'stage_price': '-', 'subcategory': 'Лента сигнальная Электра - ЛСЭ', 'specs': "{'Толщина': '300 мкм', 'Ширина': '750 мм', 'Размер': '100 п.м.'}", 'title': 'Лента ОСТОРОЖНО КАБЕЛЬ', 'image': 'lenti/kab.jpg', 'price': '3102', 'category': 14}
# 2016-09-14 18:47:04,598 INFO sqlalchemy.engine.base.Engine COMMIT
# 2016-09-14 18:47:04,604 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2016-09-14 18:47:04,605 INFO sqlalchemy.engine.base.Engine INSERT INTO products (category, subcategory, title, specs, price, stage_price, image) VALUES (%(category)s, %(subcategory)s, %(title)s, %(specs)s, %(price)s, %(stage_price)s, %(image)s)
